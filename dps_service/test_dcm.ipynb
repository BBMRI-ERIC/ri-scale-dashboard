# %% [markdown]
# Convert svs to dcm, open in Openslide and check diff and attributes

# %%
import openslide
import numpy as np
from PIL import Image
print(openslide.__version__)
# Out:
# 1.4.3

# %%
# %%sh
#
# rm -rf ./data/dicom_dicomizer/*
# mkdir -p ./data/dicom_dicomizer/
#
# wsidicomizer -i "./data/wsi/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51.svs" \
#             -o ./data/dicom_dicomizer/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51 \
#             --source opentile \
#             -t 256 \
#             --format jpeg \
#             --quality 100 \
#             -w 20 \
#             -l 0

# %%
# %%sh
#
# rm -rf ./data/dicom_wsi2dcm/*
# mkdir -p ./data/dicom_wsi2dcm/
#
# wsi2dcm --input ./data/wsi/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51.svs --outFolder ./data/dicom_wsi2dcm --seriesDescription "" --tileHeight 256 --tileWidth 256 --compression jpeg --threads 20
# Out:
# [2026-01-08 13:58:43.618200] [0x000075de4ffc09c0] [warning] studyId is going to be generated
# [2026-01-08 13:58:43.618228] [0x000075de4ffc09c0] [warning] seriesId is going to be generated
# [2026-01-08 13:58:43.618231] [0x000075de4ffc09c0] [warning] batch parameter is not set, batch is unlimited
# [2026-01-08 13:58:43.636822] [0x000075de4ffc09c0] [info]    dicomization is started
# [2026-01-08 14:11:59.750762] [0x000075de4ffc09c0] [info]    dicomization is done
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('sh', '', '\nrm -rf ./data/dicom_wsi2dcm/*\nmkdir -p ./data/dicom_wsi2dcm/\n\nwsi2dcm --input ./data/wsi/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51.svs --outFolder ./data/dicom_wsi2dcm --seriesDescription "" --tileHeight 256 --tileWidth 256 --compression jpeg --threads 20\n')
#
# File ~/Documents/RIScale/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/RIScale/.venv/lib/python3.11/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File ~/Documents/RIScale/.venv/lib/python3.11/site-packages/IPython/core/magics/script.py:348, in ScriptMagics.shebang(self, line, cell)
#     343 if args.raise_error and p.returncode != 0:
#     344     # If we get here and p.returncode is still None, we must have
#     345     # killed it but not yet seen its return code. We don't wait for it,
#     346     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     347     rc = p.returncode or -9
# --> 348     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\nrm -rf ./data/dicom_wsi2dcm/*\nmkdir -p ./data/dicom_wsi2dcm/\n\nwsi2dcm --input ./data/wsi/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51.svs --outFolder ./data/dicom_wsi2dcm --seriesDescription "" --tileHeight 256 --tileWidth 256 --compression jpeg --threads 20\n'' returned non-zero exit status 1.

# %%
svs_path = "./data/wsi/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51.svs"
dcm_google_path = "./data/dicom_wsi2dcm/level-0-frames-0-165396.dcm"
dcm_path = "./data/dicom_dicomizer/TCGA-C5-A0TN-01Z-00-DX1.D5AB52B6-AD7D-494F-B1AC-E3A72EAD9F51/1.2.826.0.1.3680043.8.498.23937244397968656497068474487612849103.dcm"

# %%
print(openslide.OpenSlide.detect_format(dcm_path))
print(openslide.OpenSlide.detect_format(dcm_google_path))
print(openslide.OpenSlide.detect_format(svs_path))
# Out:
# dicom
# dicom
# aperio

# %%
svs = openslide.OpenSlide(svs_path)

# %%
dcm = openslide.OpenSlide(dcm_path)

# %%
dcm_google = openslide.OpenSlide(dcm_google_path)

# %%
print(f"Levels:\n  SVS:            {svs.level_count}\n  DCM(dicomizer): {dcm.level_count}\n  DCM(wsi2dcm):   {dcm_google.level_count}\n")
print(f"Dimensions:\n  SVS:            {svs.dimensions}\n  DCM(dicomizer): {dcm.dimensions}\n  DCM(wsi2dcm):   {dcm_google.dimensions}\n")
print(f"Downsamples:\n  SVS:            {svs.level_downsamples}\n  DCM(dicomizer): {dcm.level_downsamples}\n  DCM(wsi2dcm):   {dcm_google.level_downsamples}\n")
print(f"Level Dimensions:\n  SVS:            {svs.level_dimensions}\n  DCM(dicomizer): {dcm.level_dimensions}\n  DCM(wsi2dcm):   {dcm_google.level_dimensions}\n")

print("\n")

#print(f"Properties:\n  SVS: {len(svs.properties)} items\n  DCM: {len(dcm.properties)} items")
#print(f"Properies Keys:\n  SVS: {list(svs.properties.keys())}\n  DCM: {list(dcm.properties.keys())}")
#print(f"Vendor:\n  SVS: {svs.properties.get(openslide.PROPERTY_NAME_VENDOR)}\n  DCM: {dcm.properties.get(openslide.PROPERTY_NAME_VENDOR)}")
#print(f"Objective Power:\n  SVS: {svs.properties.get(openslide.PROPERTY_NAME_OBJECTIVE_POWER)}\n  DCM: {dcm.properties.get(openslide.PROPERTY_NAME_OBJECTIVE_POWER)}")

#Go through each property and comprare

#get keys of svs and dcm and make union
keys_union = set(svs.properties.keys()) | set(dcm.properties.keys()) | set(dcm_google.properties.keys())

for key in keys_union:
    svs_value = svs.properties.get(key)
    dcm_value = dcm.properties.get(key)
    dcm_google_value = dcm_google.properties.get(key)
    if svs_value != dcm_value or svs_value != dcm_google_value:
        print(f"Property '{key}' differs:\n  SVS: {svs_value}\n  DCM(dicomizer): {dcm_value}\n  DCM(wsi2dcm): {dcm_google_value}\n")
    else:
        print(f"Property '{key}' matches: {svs_value}")
# Out:
# Levels:
#   SVS:            4
#   DCM(dicomizer): 4
#   DCM(wsi2dcm):   4
#
# Dimensions:
#   SVS:            (118080, 91478)
#   DCM(dicomizer): (118080, 91478)
#   DCM(wsi2dcm):   (118080, 91478)
#
# Downsamples:
#   SVS:            (1.0, 4.000043727316454, 16.000524750743395, 32.0038488453464)
#   DCM(dicomizer): (1.0, 4.000043727316454, 16.000524750743395, 32.0038488453464)
#   DCM(wsi2dcm):   (1.0, 4.000043727316454, 16.000524750743395, 32.0038488453464)
#
# Level Dimensions:
#   SVS:            ((118080, 91478), (29520, 22869), (7380, 5717), (3690, 2858))
#   DCM(dicomizer): ((118080, 91478), (29520, 22869), (7380, 5717), (3690, 2858))
#   DCM(wsi2dcm):   ((118080, 91478), (29520, 22869), (7380, 5717), (3690, 2858))
#
#
#
# Property 'dicom.StudyInstanceUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.84563317270094250477705012104408964577
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.2.8323329.22113.1767877123.618845
#
# Property 'dicom.DimensionIndexSequence[1].FunctionalGroupPointer[0]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 72
#
# Property 'dicom.FrameOfReferenceUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.86362807222196545596159322316685268637
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.3.8323329.22113.1767877123.618846.1
#
# Property 'openslide.level[3].width' matches: 3690
# Property 'dicom.SpecimenDescriptionSequence[0].SpecimenTypeCodeSequence[0].CodeValue' differs:
#   SVS: None
#   DCM(dicomizer): 1179252003
#   DCM(wsi2dcm): None
#
# Property 'dicom.DimensionIndexSequence[0].DimensionOrganizationUID' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.2.8323329.22113.1767877915.618854
#
# Property 'dicom.ContentTime' differs:
#   SVS: None
#   DCM(dicomizer): 152723.337188
#   DCM(wsi2dcm): 131155
#
# Property 'dicom.OpticalPathSequence[0].IlluminationColorCodeSequence[0].CodingSchemeDesignator' differs:
#   SVS: None
#   DCM(dicomizer): SCT
#   DCM(wsi2dcm): None
#
# Property 'dicom.AccessionNumber' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.AcquisitionDateTime' differs:
#   SVS: None
#   DCM(dicomizer): 20130409203622
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[3].downsample' matches: 32.003848845346397
# Property 'aperio.Left' differs:
#   SVS: 35.050957
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.StripeWidth' differs:
#   SVS: 1000
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[1].downsample' matches: 4.000043727316454
# Property 'dicom.ImagedVolumeDepth' differs:
#   SVS: None
#   DCM(dicomizer): 0.5
#   DCM(wsi2dcm): None
#
# Property 'dicom.PatientBirthDate' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.LossyImageCompression' differs:
#   SVS: None
#   DCM(dicomizer): 01
#   DCM(wsi2dcm): 01
#
# Property 'openslide.level[0].tile-height' matches: 256
# Property 'dicom.SharedFunctionalGroupsSequence[0].WholeSlideMicroscopyImageFrameTypeSequence[0].FrameType[1]' differs:
#   SVS: None
#   DCM(dicomizer): PRIMARY
#   DCM(wsi2dcm): None
#
# Property 'dicom.ContentDate' differs:
#   SVS: None
#   DCM(dicomizer): 20260112
#   DCM(wsi2dcm): 20260108
#
# Property 'dicom.LossyImageCompressionMethod' differs:
#   SVS: None
#   DCM(dicomizer): ISO_10918_1
#   DCM(wsi2dcm): None
#
# Property 'aperio.LineAreaXOffset' differs:
#   SVS: 0.038321
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.DimensionIndexSequence[0].FunctionalGroupPointer[1]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 538
#
# Property 'aperio.AppMag' differs:
#   SVS: 40
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImplementationClassUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.1
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.0.
#
# Property 'dicom.MediaStorageSOPInstanceUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.65196204978648658763452120015699327727
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.4.8323329.22113.1767877915.618853
#
# Property 'dicom.OpticalPathSequence[0].IlluminationTypeCodeSequence[0].CodeMeaning' differs:
#   SVS: None
#   DCM(dicomizer): Brightfield illumination
#   DCM(wsi2dcm): None
#
# Property 'openslide.mpp-y' differs:
#   SVS: 0.25009999999999999
#   DCM(dicomizer): 0.25009999999999999
#   DCM(wsi2dcm): 0.25
#
# Property 'openslide.level[3].tile-height' matches: 256
# Property 'tiff.ImageDescription' differs:
#   SVS: Aperio Image Library v11.2.1
# 118080x91478 (256x256) JPEG/RGB Q=30;Aperio Image Library vFS90 01
# 123000x91578 [0,100 118080x91478] (256x256) J2K/YUV16 Q=70|AppMag = 40|StripeWidth = 1000|ScanScope ID = SS1289|Filename = 87881|Date = 04/09/13|Time = 20:36:22|Time Zone = GMT-05:00|User = 4c6c76ae-0e46-4569-8284-b2d3f3fbb78b|MPP = 0.2501|Left = 35.050957|Top = 23.231928|LineCameraSkew = 0.002004|LineAreaXOffset = 0.038321|LineAreaYOffset = 0.004639|Focus Offset = 0.000000|DSR ID = spdigimg-dsr|ImageID = 87881|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|OriginalWidth = 123000|OriginalHeight = 91578|ICC Profile = ScanScope v1
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.ManufacturerModelName' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'dicom.ContainerTypeCodeSequence[0].CodingSchemeDesignator' differs:
#   SVS: None
#   DCM(dicomizer): SCT
#   DCM(wsi2dcm): None
#
# Property 'dicom.DimensionIndexSequence[1].DimensionIndexPointer[0]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 72
#
# Property 'dicom.BitsStored' differs:
#   SVS: None
#   DCM(dicomizer): 8
#   DCM(wsi2dcm): 8
#
# Property 'dicom.StudyDate' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.TotalPixelMatrixOriginSequence[0].XOffsetInSlideCoordinateSystem' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): None
#
# Property 'openslide.associated.thumbnail.height' differs:
#   SVS: 768
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.Date' differs:
#   SVS: 04/09/13
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.LineAreaYOffset' differs:
#   SVS: 0.004639
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.MPP' differs:
#   SVS: 0.2501
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.DimensionIndexSequence[1].FunctionalGroupPointer[1]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 538
#
# Property 'dicom.ImageOrientationSlide[4]' differs:
#   SVS: None
#   DCM(dicomizer): 1.0
#   DCM(wsi2dcm): 0
#
# Property 'dicom.InstanceNumber' differs:
#   SVS: None
#   DCM(dicomizer): 0
#   DCM(wsi2dcm): 1
#
# Property 'dicom.StudyID' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.OpticalPathSequence[0].IlluminationColorCodeSequence[0].CodeValue' differs:
#   SVS: None
#   DCM(dicomizer): 414298005
#   DCM(wsi2dcm): None
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].PixelMeasuresSequence[0].SliceThickness' differs:
#   SVS: None
#   DCM(dicomizer): 0.0005
#   DCM(wsi2dcm): None
#
# Property 'dicom.NumberOfOpticalPaths' differs:
#   SVS: None
#   DCM(dicomizer): 1
#   DCM(wsi2dcm): None
#
# Property 'aperio.ICC Profile' differs:
#   SVS: ScanScope v1
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].WholeSlideMicroscopyImageFrameTypeSequence[0].FrameType[0]' differs:
#   SVS: None
#   DCM(dicomizer): ORIGINAL
#   DCM(wsi2dcm): None
#
# Property 'dicom.FocusMethod' differs:
#   SVS: None
#   DCM(dicomizer): AUTO
#   DCM(wsi2dcm): None
#
# Property 'dicom.SpecimenDescriptionSequence[0].SpecimenTypeCodeSequence[0].CodeMeaning' differs:
#   SVS: None
#   DCM(dicomizer): Slide
#   DCM(wsi2dcm): None
#
# Property 'dicom.ContainerIdentifier' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[3].height' matches: 2858
# Property 'dicom.NumberOfFrames' differs:
#   SVS: None
#   DCM(dicomizer): 165396
#   DCM(wsi2dcm): 165396
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].WholeSlideMicroscopyImageFrameTypeSequence[0].FrameType[2]' differs:
#   SVS: None
#   DCM(dicomizer): VOLUME
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[1].width' matches: 29520
# Property 'dicom.LossyImageCompressionRatio' differs:
#   SVS: None
#   DCM(dicomizer): 12.53
#   DCM(wsi2dcm): None
#
# Property 'dicom.ContainerTypeCodeSequence[0].CodeMeaning' differs:
#   SVS: None
#   DCM(dicomizer): Microscope slide
#   DCM(wsi2dcm): None
#
# Property 'aperio.Exposure Scale' differs:
#   SVS: 0.000001
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImageType[3]' differs:
#   SVS: None
#   DCM(dicomizer): NONE
#   DCM(wsi2dcm): NONE
#
# Property 'dicom.OpticalPathSequence[0].IlluminationTypeCodeSequence[0].CodingSchemeDesignator' differs:
#   SVS: None
#   DCM(dicomizer): DCM
#   DCM(wsi2dcm): None
#
# Property 'tiff.ResolutionUnit' differs:
#   SVS: inch
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.VolumetricProperties' differs:
#   SVS: None
#   DCM(dicomizer): VOLUME
#   DCM(wsi2dcm): None
#
# Property 'dicom.PlanarConfiguration' differs:
#   SVS: None
#   DCM(dicomizer): 0
#   DCM(wsi2dcm): 0
#
# Property 'openslide.level[0].width' matches: 118080
# Property 'aperio.Time' differs:
#   SVS: 20:36:22
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.User' differs:
#   SVS: 4c6c76ae-0e46-4569-8284-b2d3f3fbb78b
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[2].tile-height' matches: 256
# Property 'openslide.comment' differs:
#   SVS: Aperio Image Library v11.2.1
# 118080x91478 (256x256) JPEG/RGB Q=30;Aperio Image Library vFS90 01
# 123000x91578 [0,100 118080x91478] (256x256) J2K/YUV16 Q=70|AppMag = 40|StripeWidth = 1000|ScanScope ID = SS1289|Filename = 87881|Date = 04/09/13|Time = 20:36:22|Time Zone = GMT-05:00|User = 4c6c76ae-0e46-4569-8284-b2d3f3fbb78b|MPP = 0.2501|Left = 35.050957|Top = 23.231928|LineCameraSkew = 0.002004|LineAreaXOffset = 0.038321|LineAreaYOffset = 0.004639|Focus Offset = 0.000000|DSR ID = spdigimg-dsr|ImageID = 87881|Exposure Time = 109|Exposure Scale = 0.000001|DisplayColor = 0|OriginalWidth = 123000|OriginalHeight = 91578|ICC Profile = ScanScope v1
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].PixelMeasuresSequence[0].PixelSpacing[0]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0002501
#   DCM(wsi2dcm): 0.000250
#
# Property 'aperio.Top' differs:
#   SVS: 23.231928
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.ImageID' differs:
#   SVS: 87881
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.Rows' differs:
#   SVS: None
#   DCM(dicomizer): 256
#   DCM(wsi2dcm): 256
#
# Property 'openslide.vendor' differs:
#   SVS: aperio
#   DCM(dicomizer): dicom
#   DCM(wsi2dcm): dicom
#
# Property 'aperio.OriginalHeight' differs:
#   SVS: 91578
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'openslide.level-count' matches: 4
# Property 'openslide.level[0].height' matches: 91478
# Property 'dicom.BitsAllocated' differs:
#   SVS: None
#   DCM(dicomizer): 8
#   DCM(wsi2dcm): 8
#
# Property 'dicom.PixelRepresentation' differs:
#   SVS: None
#   DCM(dicomizer): 0
#   DCM(wsi2dcm): 0
#
# Property 'openslide.associated.thumbnail.width' differs:
#   SVS: 991
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.ReferringPhysicianName' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[2].height' matches: 5717
# Property 'dicom.SOPInstanceUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.65196204978648658763452120015699327727
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.4.8323329.22113.1767877915.618853
#
# Property 'dicom.ImageType[2]' differs:
#   SVS: None
#   DCM(dicomizer): VOLUME
#   DCM(wsi2dcm): VOLUME
#
# Property 'dicom.OpticalPathSequence[0].IlluminationColorCodeSequence[0].CodeMeaning' differs:
#   SVS: None
#   DCM(dicomizer): Full Spectrum
#   DCM(wsi2dcm): None
#
# Property 'dicom.TotalPixelMatrixColumns' differs:
#   SVS: None
#   DCM(dicomizer): 118080
#   DCM(wsi2dcm): 118080
#
# Property 'openslide.level[2].downsample' matches: 16.000524750743395
# Property 'dicom.TotalPixelMatrixFocalPlanes' differs:
#   SVS: None
#   DCM(dicomizer): 1
#   DCM(wsi2dcm): None
#
# Property 'dicom.SeriesNumber' differs:
#   SVS: None
#   DCM(dicomizer): 1
#   DCM(wsi2dcm): None
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].PixelMeasuresSequence[0].PixelSpacing[1]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0002501
#   DCM(wsi2dcm): 0.000250
#
# Property 'openslide.mpp-x' differs:
#   SVS: 0.25009999999999999
#   DCM(dicomizer): 0.25009999999999999
#   DCM(wsi2dcm): 0.25
#
# Property 'aperio.DisplayColor' differs:
#   SVS: 0
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.PositionReferenceIndicator' differs:
#   SVS: None
#   DCM(dicomizer): SLIDE_CORNER
#   DCM(wsi2dcm): None
#
# Property 'dicom.StudyTime' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.ContainerTypeCodeSequence[0].CodeValue' differs:
#   SVS: None
#   DCM(dicomizer): 433466003
#   DCM(wsi2dcm): None
#
# Property 'dicom.PatientID' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImageOrientationSlide[3]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): -1
#
# Property 'openslide.level[0].downsample' matches: 1
# Property 'dicom.DimensionIndexSequence[0].DimensionIndexPointer[1]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 542
#
# Property 'dicom.SOPClassUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.840.10008.5.1.4.1.1.77.1.6
#   DCM(wsi2dcm): 1.2.840.10008.5.1.4.1.1.77.1.6
#
# Property 'openslide.level[1].tile-width' matches: 256
# Property 'dicom.ImageType[1]' differs:
#   SVS: None
#   DCM(dicomizer): PRIMARY
#   DCM(wsi2dcm): PRIMARY
#
# Property 'openslide.quickhash-1' differs:
#   SVS: None
#   DCM(dicomizer): f7cb882323afa3e103ecb4e504fdbaed66297b7dc337e83ee6bd9229932024e4
#   DCM(wsi2dcm): 708189b735129ff23d29f74bc40bcfe9076ce5374c486c7cdbb4b1e4e8717c84
#
# Property 'openslide.level[2].tile-width' matches: 256
# Property 'dicom.MediaStorageSOPClassUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.840.10008.5.1.4.1.1.77.1.6
#   DCM(wsi2dcm): 1.2.840.10008.5.1.4.1.1.77.1.6
#
# Property 'dicom.DimensionIndexSequence[0].FunctionalGroupPointer[0]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 72
#
# Property 'aperio.LineCameraSkew' differs:
#   SVS: 0.002004
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.SharedFunctionalGroupsSequence[0].WholeSlideMicroscopyImageFrameTypeSequence[0].FrameType[3]' differs:
#   SVS: None
#   DCM(dicomizer): NONE
#   DCM(wsi2dcm): None
#
# Property 'aperio.Time Zone' differs:
#   SVS: GMT-05:00
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.RepresentativeFrameNumber' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 1
#
# Property 'dicom.SpecimenLabelInImage' differs:
#   SVS: None
#   DCM(dicomizer): NO
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[1].tile-height' matches: 256
# Property 'dicom.HighBit' differs:
#   SVS: None
#   DCM(dicomizer): 7
#   DCM(wsi2dcm): 7
#
# Property 'openslide.level[3].tile-width' matches: 256
# Property 'dicom.ImplementationVersionName' differs:
#   SVS: None
#   DCM(dicomizer): PYDICOM 3.0.1
#   DCM(wsi2dcm): OFFIS_DCMTK_
#
# Property 'dicom.PatientName' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'dicom.TotalPixelMatrixOriginSequence[0].ZOffsetInSlideCoordinateSystem' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): None
#
# Property 'dicom.SpecimenDescriptionSequence[0].SpecimenTypeCodeSequence[0].CodingSchemeDesignator' differs:
#   SVS: None
#   DCM(dicomizer): SCT
#   DCM(wsi2dcm): None
#
# Property 'dicom.TotalPixelMatrixRows' differs:
#   SVS: None
#   DCM(dicomizer): 91478
#   DCM(wsi2dcm): 91478
#
# Property 'dicom.SpecimenDescriptionSequence[0].SpecimenIdentifier' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[0].tile-width' matches: 256
# Property 'dicom.ImageOrientationSlide[2]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): 0
#
# Property 'dicom.DimensionIndexSequence[1].DimensionIndexPointer[1]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 542
#
# Property 'aperio.Filename' differs:
#   SVS: 87881
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImagedVolumeWidth' differs:
#   SVS: None
#   DCM(dicomizer): 29.531808853149414
#   DCM(wsi2dcm): 29.531808853149414
#
# Property 'dicom.SpecimenDescriptionSequence[0].SpecimenUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.13120740339648746029278105817157634399
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImageOrientationSlide[5]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): 0
#
# Property 'dicom.Manufacturer' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImageOrientationSlide[0]' differs:
#   SVS: None
#   DCM(dicomizer): -1.0
#   DCM(wsi2dcm): 0
#
# Property 'dicom.OpticalPathSequence[0].OpticalPathIdentifier' differs:
#   SVS: None
#   DCM(dicomizer): 0
#   DCM(wsi2dcm): None
#
# Property 'aperio.Exposure Time' differs:
#   SVS: 109
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'aperio.DSR ID' differs:
#   SVS: spdigimg-dsr
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.BurnedInAnnotation' differs:
#   SVS: None
#   DCM(dicomizer): NO
#   DCM(wsi2dcm): None
#
# Property 'dicom.Columns' differs:
#   SVS: None
#   DCM(dicomizer): 256
#   DCM(wsi2dcm): 256
#
# Property 'dicom.DimensionIndexSequence[0].DimensionIndexPointer[0]' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 72
#
# Property 'aperio.ScanScope ID' differs:
#   SVS: SS1289
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'openslide.level[2].width' matches: 7380
# Property 'openslide.level[1].height' matches: 22869
# Property 'dicom.DeviceSerialNumber' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'dicom.SeriesInstanceUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.63070540496711030054795038117511143065
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.3.8323329.22113.1767877123.618846
#
# Property 'dicom.PatientSex' differs:
#   SVS: None
#   DCM(dicomizer):
#   DCM(wsi2dcm): None
#
# Property 'openslide.icc-size' differs:
#   SVS: 141992
#   DCM(dicomizer): 141992
#   DCM(wsi2dcm): None
#
# Property 'dicom.PhotometricInterpretation' differs:
#   SVS: None
#   DCM(dicomizer): RGB
#   DCM(wsi2dcm): RGB
#
# Property 'dicom.ImageOrientationSlide[1]' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): -1
#
# Property 'dicom.ImageType[0]' differs:
#   SVS: None
#   DCM(dicomizer): ORIGINAL
#   DCM(wsi2dcm): DERIVED
#
# Property 'dicom.TotalPixelMatrixOriginSequence[0].YOffsetInSlideCoordinateSystem' differs:
#   SVS: None
#   DCM(dicomizer): 0.0
#   DCM(wsi2dcm): None
#
# Property 'dicom.ImagedVolumeHeight' differs:
#   SVS: None
#   DCM(dicomizer): 22.878646850585938
#   DCM(wsi2dcm): 22.878646850585938
#
# Property 'aperio.OriginalWidth' differs:
#   SVS: 123000
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.DimensionOrganizationSequence[0].DimensionOrganizationUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.826.0.1.3680043.8.498.16771647436871618702986436261896182342
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.2.8323329.22113.1767877915.618854
#
# Property 'dicom.DimensionOrganizationType' differs:
#   SVS: None
#   DCM(dicomizer): TILED_FULL
#   DCM(wsi2dcm): TILED_FULL
#
# Property 'dicom.ExtendedDepthOfField' differs:
#   SVS: None
#   DCM(dicomizer): NO
#   DCM(wsi2dcm): None
#
# Property 'dicom.SamplesPerPixel' differs:
#   SVS: None
#   DCM(dicomizer): 3
#   DCM(wsi2dcm): 3
#
# Property 'dicom.DimensionIndexSequence[1].DimensionOrganizationUID' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm): 1.2.276.0.7230010.3.1.2.8323329.22113.1767877915.618854
#
# Property 'dicom.SeriesDescription' differs:
#   SVS: None
#   DCM(dicomizer): None
#   DCM(wsi2dcm):
#
# Property 'dicom.Modality' differs:
#   SVS: None
#   DCM(dicomizer): SM
#   DCM(wsi2dcm): SM
#
# Property 'openslide.objective-power' differs:
#   SVS: 40
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None
#
# Property 'dicom.OpticalPathSequence[0].IlluminationTypeCodeSequence[0].CodeValue' differs:
#   SVS: None
#   DCM(dicomizer): 111744
#   DCM(wsi2dcm): None
#
# Property 'dicom.SoftwareVersions' differs:
#   SVS: None
#   DCM(dicomizer): Unknown
#   DCM(wsi2dcm): None
#
# Property 'dicom.TransferSyntaxUID' differs:
#   SVS: None
#   DCM(dicomizer): 1.2.840.10008.1.2.4.50
#   DCM(wsi2dcm): 1.2.840.10008.1.2.4.50
#
# Property 'aperio.Focus Offset' differs:
#   SVS: 0.000000
#   DCM(dicomizer): None
#   DCM(wsi2dcm): None

# %%
x, y, w, h = 10000, 10000, 64, 64

region_svs = svs.read_region((x, y), 0, (w, h))
region_dcm = dcm.read_region((x, y), 0, (w, h))
region_dcm_google = dcm_google.read_region((x, y), 0, (w, h))

arr_svs = np.array(region_svs)[:, :, :3]
arr_dcm = np.array(region_dcm)[:, :, :3]
arr_dcm_google = np.array(region_dcm_google)[:, :, :3]


diff_svs_svs = np.abs(arr_svs.astype(int) - arr_svs.astype(int))
diff_svs_dcm = np.abs(arr_svs.astype(int) - arr_dcm.astype(int))
diff_svs_dcm_google = np.abs(arr_svs.astype(int) - arr_dcm_google.astype(int))


mean_diff_svs_svs = np.mean(diff_svs_svs)
mean_diff_dcm = np.mean(diff_svs_dcm)
mean_diff_dcm_google = np.mean(diff_svs_dcm_google)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

axes[0, 0].imshow(arr_svs)
axes[0, 0].set_title('SVS')
axes[0, 0].axis('off')

axes[0, 1].imshow(arr_dcm)
axes[0, 1].set_title('DCM (dicomizer)')
axes[0, 1].axis('off')

axes[0, 2].imshow(arr_dcm_google)
axes[0, 2].set_title('DCM (wsi2dcm)')
axes[0, 2].axis('off')

#axes[1, 0].imshow(diff_svs_svs)
axes[1, 0].axis('off')

axes[1, 1].imshow(diff_svs_dcm)
axes[1, 1].set_title(f'Diff: SVS vs DCM(dicomizer)\nMean: {mean_diff_dcm:.2f}')
axes[1, 1].axis('off')

axes[1, 2].imshow(diff_svs_dcm_google)
axes[1, 2].set_title(f'Diff: SVS vs DCM(wsi2dcm)\nMean: {mean_diff_dcm_google:.2f}')
axes[1, 2].axis('off')

plt.tight_layout()
plt.show()
